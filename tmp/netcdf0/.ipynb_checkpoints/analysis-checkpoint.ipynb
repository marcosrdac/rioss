# %% [markdown]
# # analysis

# %%
import numpy as np
import netCDF4 as nc
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
from PIL import Image
from functions import *

# %%
df = pd.DataFrame(columns=['x','y','value','3x3avg','3x3std','label'])
df['x']         = np.load('x.npy')
df['y']         = np.load('y.npy')
df['value']     = np.load('value.npy')
df['avg3x3']    = np.load('avg3x3.npy')
df['std3x3']    = np.load('std3x3.npy')
df['value-avg3x3oavg'] = (df['value']-df['avg3x3'])
df['std/avg']   = df['3x3std']/df['3x3avg']
df['label']     = np.load('labels.npy')*1
df.dropna(inplace=True)

# %%
df.head()
# Out:
#        x    y  value     3x3avg     3x3std  label  value-avg   std/avg
# 0  11101  574     76  59.444444  21.092975      0  16.555556  0.354835
# 1  11104  574     34  39.555556  23.622546      0  -5.555556  0.597199
# 2  11107  574     21  34.333333  31.091264      0 -13.333333  0.905571
# 3  11110  574     21  36.888889  25.379101      0 -15.888889  0.687988
# 4  11113  574     24  58.111111  28.505144      0 -34.111111  0.490528

# %%
sns.heatmap(df[['value', '3x3avg', '3x3std', 'value-avg', 'std/avg','label']].corr(), annot=True)

# %%
sns.pairplot(df, vars=['3x3avg','label'])

# %%
sns.pairplot(df, hue='label', vars=['3x3avg','3x3std'])

# %%
sns.pairplot(df, hue='label', vars=['value','3x3avg','3x3std','std/avg','label'])

# %%
df.head()
# Out:
#        x    y  value     3x3avg     3x3std  label   std/avg
# 0  11101  574     76  59.444444  21.092975      0  0.354835
# 1  11104  574     34  39.555556  23.622546      0  0.597199
# 2  11107  574     21  34.333333  31.091264      0  0.905571
# 3  11110  574     21  36.888889  25.379101      0  0.687988
# 4  11113  574     24  58.111111  28.505144      0  0.490528

# %%
X = df[['value','3x3avg','3x3std','std/avg',]]
y = df['label']

#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(X_train, y_train)

y_pred = logmodel.predict(X_test)
# Out:
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(pd.DataFrame(data=confusion_matrix(y_test, y_pred),
                   index=['Actually True','Actually False'],
                   columns=['Predicted True','Predicted False']))

print(classification_report(y_test, y_pred))
# Out:
#                 Predicted True  Predicted False
# Actually True          2782756            41545
# Actually False          200272            43093
#               precision    recall  f1-score   support
#
#            0       0.93      0.99      0.96   2824301
#            1       0.51      0.18      0.26    243365
#
#     accuracy                           0.92   3067666
#    macro avg       0.72      0.58      0.61   3067666
# weighted avg       0.90      0.92      0.90   3067666

# %%
sns.countplot(df['label'])

# %%
df.drop(df.query('label == 0').sample(frac=.9).index, inplace=True)

# %%
sns.countplot(df['label'])

# %%
sns.pairplot(df, hue='label', vars=['value','3x3avg','3x3std','std/avg'])

# %%
X = df[['value','3x3avg','3x3std','std/avg',]]
y = df['label']

#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(X_train, y_train)

y_pred = logmodel.predict(X_test)


from sklearn.metrics import confusion_matrix, classification_report

print(pd.DataFrame(data=confusion_matrix(y_test, y_pred),
                   index=['Actually True','Actually False'],
                   columns=['Predicted True','Predicted False']))

print()

print(classification_report(y_test, y_pred))
# Out:
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#                 Predicted True  Predicted False
# Actually True           230665            51460
# Actually False           24570           219586
#
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86    282125
#            1       0.81      0.90      0.85    244156
#
#     accuracy                           0.86    526281
#    macro avg       0.86      0.86      0.86    526281
# weighted avg       0.86      0.86      0.86    526281

# %%
from pickle import dumps, loads
text_model1 = dumps(logmodel)

# %%
text_model=b'\x80\x03csklearn.linear_model.logistic\nLogisticRegression\nq\x00)\x81q\x01}q\x02(X\x07\x00\x00\x00penaltyq\x03X\x02\x00\x00\x00l2q\x04X\x04\x00\x00\x00dualq\x05\x89X\x03\x00\x00\x00tolq\x06G?\x1a6\xe2\xeb\x1cC-X\x01\x00\x00\x00Cq\x07G?\xf0\x00\x00\x00\x00\x00\x00X\r\x00\x00\x00fit_interceptq\x08\x88X\x11\x00\x00\x00intercept_scalingq\tK\x01X\x0c\x00\x00\x00class_weightq\nNX\x0c\x00\x00\x00random_stateq\x0bNX\x06\x00\x00\x00solverq\x0cX\x04\x00\x00\x00warnq\rX\x08\x00\x00\x00max_iterq\x0eKdX\x0b\x00\x00\x00multi_classq\x0fh\rX\x07\x00\x00\x00verboseq\x10K\x00X\n\x00\x00\x00warm_startq\x11\x89X\x06\x00\x00\x00n_jobsq\x12NX\x08\x00\x00\x00l1_ratioq\x13NX\x08\x00\x00\x00classes_q\x14cnumpy.core.multiarray\n_reconstruct\nq\x15cnumpy\nndarray\nq\x16K\x00\x85q\x17C\x01bq\x18\x87q\x19Rq\x1a(K\x01K\x02\x85q\x1bcnumpy\ndtype\nq\x1cX\x02\x00\x00\x00i8q\x1dK\x00K\x01\x87q\x1eRq\x1f(K\x03X\x01\x00\x00\x00<q NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00tq!b\x89C\x10\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00q"tq#bX\x05\x00\x00\x00coef_q$h\x15h\x16K\x00\x85q%h\x18\x87q&Rq\'(K\x01K\x01K\x04\x86q(h\x1cX\x02\x00\x00\x00f8q)K\x00K\x01\x87q*Rq+(K\x03h NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00tq,b\x89C \x82\r\x9f\x10\xd5\x10m?\xe7j\x02`)\x96\xbc\xbf23_\x9b}6\xa4\xbf5\xc5\x02#_Z\xe6\xbfq-tq.bX\n\x00\x00\x00intercept_q/h\x15h\x16K\x00\x85q0h\x18\x87q1Rq2(K\x01K\x01\x85q3h+\x89C\x08\xfe$\xcd\xfd\xe8i\x13@q4tq5bX\x07\x00\x00\x00n_iter_q6h\x15h\x16K\x00\x85q7h\x18\x87q8Rq9(K\x01K\x01\x85q:h\x1cX\x02\x00\x00\x00i4q;K\x00K\x01\x87q<Rq=(K\x03h NNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00tq>b\x89C\x04\x0f\x00\x00\x00q?tq@bX\x10\x00\x00\x00_sklearn_versionqAX\x06\x00\x00\x000.21.3qBub.'

# %%
from pickle import dumps, loads
logmodel = loads(text_model)

y_pred = logmodel.predict(X_test)

print(pd.DataFrame(data=confusion_matrix(y_test, y_pred),
                   index=['Actually True','Actually False'],
                   columns=['Predicted True','Predicted False']))
print(classification_report(y_test, y_pred))
# Out:
#                 Predicted True  Predicted False
# Actually True           229991            52385
# Actually False           23938           219967
#               precision    recall  f1-score   support
#
#            0       0.91      0.81      0.86    282376
#            1       0.81      0.90      0.85    243905
#
#     accuracy                           0.85    526281
#    macro avg       0.86      0.86      0.85    526281
# weighted avg       0.86      0.85      0.86    526281
